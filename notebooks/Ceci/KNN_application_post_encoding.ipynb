# %%
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report
from sklearn.preprocessing import LabelEncoder
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error, r2_score

# %%
url = 'https://raw.githubusercontent.com/alvarofavale/week7_ml/refs/heads/main/notebooks/Ceci/encoded_data.csv'
df = pd.read_csv(url)

# Set display option to show all columns
pd.set_option('display.max_columns', None)

df.head()
# Out:
#    customer_id  month   age occupation  annual_income  monthly_inhand_salary  \
# 0         3392      1  23.0        1.0       19114.12            1824.843333
# 1         3392      2  23.0        1.0       19114.12            1824.843333
# 2         3392      3  23.0        1.0       19114.12            1824.843333
# 3         3392      4  23.0        1.0       19114.12            1824.843333
# 4         3392      5  23.0        1.0       19114.12            1824.843333
#
#    num_bank_accounts  num_credit_card  interest_rate  num_of_loan  \
# 0                3.0              4.0            3.0          4.0
# 1                3.0              4.0            3.0          4.0
# 2                3.0              4.0            3.0          4.0
# 3                3.0              4.0            3.0          4.0
# 4                3.0              4.0            3.0          4.0
#
#    type_of_loan  delay_from_due_date  num_of_delayed_payment  \
# 0         269.0                  3.0                     7.0
# 1         269.0                  3.0                     4.0
# 2         269.0                  3.0                     7.0
# 3         269.0                  5.0                     4.0
# 4         269.0                  6.0                     4.0
#
#    changed_credit_limit  num_credit_inquiries  credit_mix  outstanding_debt  \
# 0                 11.27                   4.0           1            809.98
# 1                 11.27                   4.0           1            809.98
# 2                 11.27                   4.0           1            809.98
# 3                  6.27                   4.0           1            809.98
# 4                 11.27                   4.0           1            809.98
#
#    credit_utilization_ratio  credit_history_age  payment_of_min_amount  \
# 0                 26.822620               265.0                      1
# 1                 31.944960               266.0                      1
# 2                 28.609352               267.0                      1
# 3                 31.377862               268.0                      1
# 4                 24.797347               269.0                      1
#
#    total_emi_per_month  amount_invested_monthly  payment_behaviour  \
# 0            49.574949                 21.46538                  1
# 1            49.574949                 21.46538                  2
# 2            49.574949                 21.46538                  3
# 3            49.574949                 21.46538                  4
# 4            49.574949                 21.46538                  5
#
#    monthly_balance  credit_score
# 0       312.494089             0
# 1       284.629162             0
# 2       331.209863             0
# 3       223.451310             0
# 4       341.489231             0
